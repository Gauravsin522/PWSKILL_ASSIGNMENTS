# %% [markdown]
# # Theoretical

# %%
# 1. What does R-squared represent in a regression model?

# Answer: R-squared (R²) indeed represents the proportion of the variance in the dependent variable that is predictable from the independent variable(s).
# It's a measure of how well the regression model fits the data

# %%
# 2. What are the assumptions of linear regression ?

# Answer: The assumptions of linear regression are:
# 1. Linearity: The relationship between the independent and dependent variables is linear.
# 2. Independence: The residuals are independent.

# %%
# 3. What is the difference between R-squared and Adjusted R-squared?

# Answer: R-squared is a measure of how well the regression model fits the data, while Adjusted R-squared is a modified version
# of R-squared that has been adjusted for the number of predictors in the model.

# %%
# 4. Why do we use Mean Squared Error (MSE)?

# Answer: Mean Squared Error (MSE) is a measure of the average squared difference between the actual and predicted values in a regression model.
# It is used to evaluate the performance of the model and to compare different models.

# %%
# 5. What does an Adjusted R-squared value of 0.85 indicate?

# Answer: An Adjusted R-squared value of 0.85 indicates that 85% of the variance in the dependent variable is predictable from the independent variable(s)
# in the regression model, after adjusting for the number of predictors in the model. It suggests that the model fits the data well.

# %%
# 6. How do we check for normality of residuals in linear regression?

# Answer: We can check for normality of residuals in linear regression by plotting a histogram of the residuals and checking if it follows a normal distribution.
# We can also use statistical tests like the Shapiro-Wilk test or the Kolmogorov-Smirnov test to test for normality.

# %%
# 7. What is multicollinearity, and how does it impact regression?

# Answer: Multicollinearity is a phenomenon in which two or more independent variables in a regression model are highly correlated with each other.
# It can impact regression by making it difficult to estimate the individual effects of the independent variables on the dependent variable,
# leading to unstable and unreliable estimates of the coefficients.

# %%
# 8. What is Mean Absolute Error (MAE)?

# Answer: Mean Absolute Error (MAE) is a measure of the average absolute difference between the actual and predicted values in a regression model.
# It is used to evaluate the performance of the model and to compare different models.

# %%
# 9. What are the benefits of using an ML pipeline?

# Answer: The benefits of using an ML pipeline include:
# 1. Automation: ML pipelines automate the process of training, testing, and deploying machine learning models, saving time and effort.
# 2. Reproducibility: ML pipelines make it easy to reproduce the results of a machine learning experiment by capturing the entire workflow.
# 3. Scalability: ML pipelines can be easily scaled to handle large datasets and complex machine learning models.
# 4. Flexibility: ML pipelines allow for easy experimentation with different algorithms, hyperparameters, and data preprocessing steps.

# %%
# 10. Why is RMSE considered more interpretable than MSE?

# Answer: RMSE (Root Mean Squared Error) is considered more interpretable than MSE (Mean Squared Error) because it is in the same units as the dependent variable,
# making it easier to interpret the error in the context of the problem. RMSE is the square root of the average squared difference between the actual and predicted values,
# while MSE is the average squared difference between the actual and predicted values.

# %%
# 11. What is pickling in Python, and how is it useful in ML?

# Answer: Pickling in Python is the process of serializing and deserializing objects to and from a byte stream. It is useful in ML for saving trained machine learning models
# to disk so that they can be reused later without having to retrain the model. Pickling allows for easy storage and retrieval of machine learning models.

# %%
# 12. What does a high R-squared value mean?

# Answer: A high R-squared value indicates that a large proportion of the variance in the dependent variable is predictable from the independent variable(s)
# in the regression model. It suggests that the model fits the data well and that the independent variables are good predictors of the dependent variable.

# %%
# 13. What happens if linear regression assumptions are violated?

# Answer: If linear regression assumptions are violated, the estimates of the coefficients may be biased and inefficient, and the predictions made by the model may be unreliable.
# Violations of the assumptions can lead to incorrect inferences and poor model performance.

# %%
# 14. How can we address multicollinearity in regression?

# Answer: Multicollinearity in regression can be addressed by:
# 1. Dropping one of the highly correlated variables.
# 2. Using regularization techniques like Lasso or Ridge regression.
# 3. Combining the correlated variables into a single composite variable.
# 4. Collecting more data to reduce the impact of multicollinearity.

# %%
# 15. How can feature selection improve model performance in regression analysis?

# Answer: Feature selection can improve model performance in regression analysis by reducing the complexity of the model and removing irrelevant or redundant features.
# This can help prevent overfitting, improve the interpretability of the model, and reduce the computational cost of training the model.

# %%
# 16. How is Adjusted R-squared calculated?

# Answer: Adjusted R-squared is calculated using the formula:
# Adjusted R-squared = 1 - (1 - R-squared) * (n - 1) / (n - k - 1)

# %%
# 17. Why is MSE sensitive to outliers?

# Answer: MSE (Mean Squared Error) is sensitive to outliers because it squares the errors between the actual and predicted values, giving more weight to large errors.
# Outliers can have a disproportionate impact on the MSE, leading to biased estimates of the model parameters and poor model performance.

# %%
# 18. What is the role of homoscedasticity in linear regression?

# Answer: Homoscedasticity is the assumption that the variance of the residuals is constant across all levels of the independent variables in a linear regression model.
# It is important for the validity of the regression model and the interpretation of the coefficients. Violations of homoscedasticity can lead to biased and inefficient estimates.

# %%
# 19. What is Root Mean Squared Error (RMSE)?

# Answer: Root Mean Squared Error (RMSE) is a measure of the average squared difference between the actual and predicted values in a regression model.
# It is the square root of the average squared difference between the actual and predicted values, and it is used to evaluate the performance of the model and to compare different models.

# %%
# 20. Why is pickling considered risky?

# Answer: Pickling is considered risky because it can be a security risk if the pickled objects are unpickled from untrusted sources.
# Unpickling maliciously crafted pickled objects can lead to code execution vulnerabilities, data leakage, and other security issues.
# It is important to only unpickle objects from trusted sources and to validate the pickled objects before unpickling them.

# %%
# 21. What alternatives exist to pickling for saving ML models?

# Answer: Alternatives to pickling for saving ML models include:
# 1. Serialization formats like JSON or XML.
# 2. Saving the model weights and architecture separately.
# 3. Using specialized model serialization libraries like joblib or dill.
# 4. Saving the model as a PMML (Predictive Model Markup Language) file.

# %%
# 22. What is heteroscedasticity, and why is it a problem?

# Answer: Heteroscedasticity is the phenomenon in which the variance of the residuals is not constant across all levels of the independent variables in a linear regression model.
# It is a problem because it violates the assumption of homoscedasticity, leading to biased and inefficient estimates of the coefficients, incorrect inferences, and unreliable predictions.

# %%
# 23. How can interaction terms enhance a regression model's predictive power?

# Answer: Interaction terms can enhance a regression model's predictive power by capturing the combined effect of two or more independent variables on the dependent variable.
# They allow the model to account for non-additive relationships between the variables and can improve the model's ability to predict the dependent variable accurately.

# %% [markdown]
# # Practical

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# 1. Write a Python script to visualize the distribution of errors (residuals) for a multiple linear regression model using Seaborn's "diamonds" dataset. 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df=sns.load_dataset('diamonds')

print(df.head())

X=df[['carat','depth','table','x','y','z']]
y=df['price']

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1,test_size=0.2)

model=LinearRegression()

# fit the model
model.fit(X_train,y_train)

# predict the values
y_pred=model.predict(X_test)

# calculate the residuals
residuals=y_test-y_pred

# plot the distribution of residuals
plt.figure(figsize=(10,6))
sns.histplot(residuals, kde=True , bins=50)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.show()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# 2. Write a Python script to calculate and print Mean Squared Error (MSE), Mean Absolute Error (MAE), and Root Mean Squared Error (RMSE) for a linear regression model.  

# Answer:- 

df=sns.load_dataset('diamonds')

print(df.head())

X=df[['carat','depth','table','x','y','z']]
y=df['price']

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1,test_size=0.2)

model=LinearRegression()

# fit the model
model.fit(X_train,y_train)

# predict the values
y_pred=model.predict(X_test)

from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error
print("mean absolute error :",mean_absolute_error(y_test,y_pred))
print("mean squared error :",mean_squared_error(y_test,y_pred))
print("root mean squared error :", root_mean_squared_error(y_test,y_pred))
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# mean absolute error : 894.8675429744311
# mean squared error : 2171054.3494385504
# root mean squared error : 1473.449812324312

# %%
# 3. Write a Python script to check if the assumptions of linear regression are met. Use a scatter plot to check linearity,
# residuals plot for homoscedasticity, and correlation matrix for multicollinearity.  

# Scatter plot to check linearity
sns.scatterplot(x=df['carat'], y=df['price'])
plt.xlabel('Carat')
plt.ylabel('Price')
plt.title('Scatter plot of Carat vs Price')
plt.show()

# Residuals plot for homoscedasticity
plt.figure(figsize=(10,6))
sns.residplot(x=y_pred, y=residuals, lowess=True)
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted values')
plt.show()

# Correlation matrix for multicollinearity
plt.figure(figsize=(10,6))
corr_matrix = X.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
# 4. Write a Python script that creates a machine learning pipeline with feature scaling and evaluates the performance of different regression models 

from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression,Ridge,ElasticNet,Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split,cross_val_score

df = sns.load_dataset("tips")

X = df["total_bill"].values.reshape(-1, 1)
y = df["tip"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

model={
    "Linear":LinearRegression(),
    "Ridge":Ridge(alpha=1.2),
    "Lasso":Lasso(1.5),
    "Elastic":ElasticNet(l1_ratio=0.5)
}

for name,model in model.items():
    pipeline=Pipeline([
        ("Scaler",StandardScaler()),
        ("Regression",model)
                      
    ])
    
    pipeline.fit(X_train,y_train)
    y_pred=pipeline.predict(X_test)
    
    r2=r2_score(y_test,y_pred)
    
    cv=cross_val_score(pipeline,X,y,cv=5)
    
    print(f"{name}:")
    print(f"R-squared score: {r2}")
    print(f"Cross-validation scores: {cv}")
    print(f"Mean CV score: {cv.mean()}")
    print("-" * 30)
# Out:
# Linear:
# R-squared score: 0.5326809678341402
# Cross-validation scores: [0.55056043 0.6192854  0.47423732 0.23796202 0.40067601]
# Mean CV score: 0.4565442358847632
# ------------------------------
# Ridge:
# R-squared score: 0.5308334195469833
# Cross-validation scores: [0.54872029 0.6187114  0.47442431 0.23999191 0.40070082]
# Mean CV score: 0.4565097434330171
# ------------------------------
# Lasso:
# R-squared score: -0.03781942453071929
# Cross-validation scores: [-0.00807469 -0.00364023 -0.04869446 -0.03434295 -0.02065051]
# Mean CV score: -0.023080567244436613
# ------------------------------
# Elastic:
# R-squared score: 0.16907399272268675
# Cross-validation scores: [0.21707184 0.29681127 0.2364258  0.18485896 0.19883153]
# Mean CV score: 0.22679988165273707
# ------------------------------

# %%
# 5. Implement a simple linear regression model on a dataset and print the model's coefficients, intercept, and R-squared score.  

df=sns.load_dataset("tips")

x=df["total_bill"].values.reshape(-1, 1)
y=df["tip"]

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score


X_train,X_test,y_train,y_test=train_test_split(x,y,random_state=1,test_size=.2)

model=LinearRegression()

model.fit(X_train,y_train)
y_pred=model.predict(X_test)

print("Models's Coefficients :",model.coef_)
print("Modesl's Intercept :",model.intercept_)
print("R-squared Score :",r2_score(y_test,y_pred))
# Out:
# Models's Coefficients : [0.09450883]
# Modesl's Intercept : 1.0891075415709743
# R-squared Score : 0.53268096783414

# %%
# 6. Write a Python script that analyzes the relationship between total bill and tip in the 'tips' dataset using simple linear regression and visualizes the results.  

df=sns.load_dataset("tips")

x=df["total_bill"].values.reshape(-1, 1)
y=df["tip"]

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x_train,X_test,y_train,y_test=train_test_split(x,y,random_state=1,test_size=.2)

model=LinearRegression()

model.fit(x_train,y_train)
y_pred=model.predict(X_test)

plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel('Total Bill')
plt.ylabel('Tips')
plt.legend()
plt.show()

# %%
# 7. Write a Python script that fits a linear regression model to a synthetic dataset with one feature. Use the 
# model to predict new values and plot the data points along with the regression line.  

np.random.seed(42)

n_samples=1000

X = 2 * np.random.rand(n_samples, 1)
y = 4 + 3 * X + np.random.randn(n_samples, 1)

pd.DataFrame({"Feature":X.flatten(),"Target":y.flatten()})

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

model=LinearRegression()

model.fit(X_train,y_train)

y_pred=model.predict(X_test)

plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Linear Regression Fit')
plt.legend()
plt.show()

# %%
# 8. Write a Python script that pickles a trained linear regression model and saves it to a file.  

np.random.seed(50)

n_samples=1000

X = 2 * np.random.rand(n_samples, 1)
y = 4 + 3 * X + np.random.randn(n_samples, 1)

pd.DataFrame({"Feature":X.flatten(),"Target":y.flatten()})

x_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

model=LinearRegression()

model.fit(X_train,y_train)

y_predict=model.predict(X_test)

plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_predict, color='red', linewidth=2, label='Predicted')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Linear Regression Fit')
plt.legend()
plt.show()

import pickle

with open('linear_regression_model.pkl', 'wb') as file:
    pickle.dump(model, file)

print("Model has been pickled and saved to linear_regression_model.pkl")
# Out:
# Model has been pickled and saved to linear_regression_model.pkl

# %%
# 9. Write a Python script that fits a polynomial regression model (degree 2) to a dataset and plots the regression curve. 


np.random.seed(500)

n_samples=1000

X = 2 * np.random.rand(n_samples, 1)
y = 4 + 3 * X + np.random.randn(n_samples, 1)

pd.DataFrame({"Feature":X.flatten(),"Target":y.flatten()})

x_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=2)
X_train_poly=poly.fit_transform(x_train)
X_test_poly=poly.transform(X_test)

model=LinearRegression()

model.fit(X_train_poly,y_train)

y_predict=model.predict(X_test_poly)

print("Model's Coefficients:", model.coef_)
print("Model's Intercept:", model.intercept_)
print("R-squared Score:", model.score(X_test_poly, y_test))

plt.scatter(X_test, y_test, color='blue', label='Actual')

X_range = np.linspace(min(X_test), max(X_test), 100).reshape(-1, 1)
X_range_poly = poly.transform(X_range)
y_range_pred = model.predict(X_range_poly)
plt.plot(X_range, y_range_pred, color='red', linewidth=2, label='Polynomial Regression (Degree 2)')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Polynomial Regression Fit (Degree 2)')
plt.legend()
plt.show()
# Out:
# Model's Coefficients: [[0.         2.71130801 0.1516898 ]]
# Model's Intercept: [4.10431311]
# R-squared Score: 0.7066183498607507

# %%
# 10. Generate synthetic data for simple linear regression (use random values for X and y) and fit a linear 
# regression model to the data. Print the model's coefficient and intercept. 

np.random.seed(50)

n_samples=1000

X = 2 * np.random.rand(n_samples, 1)
y = 4 + 3 * X + np.random.randn(n_samples, 1)

pd.DataFrame({"Feature":X.flatten(),"Target":y.flatten()})


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

model = LinearRegression()

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Models's Coefficients :",model.coef_)
print("Modesl's Intercept :",model.intercept_)
print("R-squared Score :",r2_score(y_test,y_pred))
# Out:
# Models's Coefficients : [[2.89907381]]
# Modesl's Intercept : [4.11882807]
# R-squared Score : 0.7173064488972122

# %%
# 11. Write a Python script that fits polynomial regression models of different degrees to a synthetic dataset and 
# compares their performance. 

n_samples=1000

X = 2 * np.random.rand(n_samples, 1)
y = 4 + 3 * X + np.random.randn(n_samples, 1)

df=pd.DataFrame({"feature":X.flatten(),"target":y.flatten()})

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

from sklearn.preprocessing import PolynomialFeatures

def fit_and_evaluate_polynomial(degree):
    poly=PolynomialFeatures(degree=degree)
    X_train_poly=poly.fit_transform(X_train)
    X_test_poly=poly.transform(X_test)
    
    model=LinearRegression()
    model.fit(X_train_poly,y_train)
    
    y_pred=model.predict(X_test_poly)
    
    mse=mean_squared_error(y_test,y_pred)
    r2=r2_score(y_test,y_pred)
    return mse,r2

degrees=[1,2,3,4,5]
result={}

for degree in degrees:
    mse,r2=fit_and_evaluate_polynomial(degree)
    result[degree]={"MSE":mse,"R_squared":r2}
    
for degree, metrics in result.items():
    print(f"Degree: {degree}")
    print(f"Mean Squared Error: {metrics['MSE']}")
    print(f"R-squared: {metrics['R_squared']}")
    print()
# Out:
# Degree: 1
# Mean Squared Error: 1.1060141865764026
# R-squared: 0.7308639050534713
#
# Degree: 2
# Mean Squared Error: 1.0995813964869823
# R-squared: 0.7324292520673614
#
# Degree: 3
# Mean Squared Error: 1.09317683105374
# R-squared: 0.7339877309290728
#
# Degree: 4
# Mean Squared Error: 1.0891337441573063
# R-squared: 0.734971570586866
#
# Degree: 5
# Mean Squared Error: 1.0897339287326282
# R-squared: 0.7348255224305134

# %%
# 12. Write a Python script that fits a simple linear regression model with two features and prints the model's coefficients, intercept, and R-squared score.  

np.random.seed(1)
n_samples = 1000
np.random.seed(0)
X = 2 * np.random.rand(n_samples, 2)  
y = 4 + 3 * X[:, 0] + 5 * X[:, 1] + np.random.randn(n_samples)

df = pd.DataFrame({"Feature1": X[:, 0], "Feature2": X[:, 1], "Target": y})

x_train, X_test, y_train, y_test=train_test_split(X,y,test_size=2,random_state=1)
model=LinearRegression()
model.fit(x_train,y_train)

y_pred=model.predict(X_test)

print(f"Coefficient :{model.coef_}")
print(f"Intercept :{model.intercept_}")
print(f"R-Squared score :{r2_score(y_test,y_pred)}")
# Out:
# Coefficient :[2.89881277 4.9314003 ]
# Intercept :4.145084603681448
# R-Squared score :-3.2935238867710854

# %%
# 13. Write a Python script that generates synthetic data, fits a linear regression model, and visualizes the regression line along with the data points.

np.random.seed(1)
n_sample=1000

X = 2 * np.random.rand(n_samples, 1)
y = 4 + 3 * X + np.random.randn(n_samples, 1)


X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,test_size=0.5)
model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

plt.figure(figsize=(10,8))
sns.scatterplot(x=X_test.flatten(),y=y_test.flatten(),label="actual")
sns.lineplot(x=X_test.flatten(), y=y_pred.flatten(), color="red", label="Regression Line")
plt.title("Linear Regression: Synthetic Data")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
sns.set(style="darkgrid")
plt.grid(True)
plt.show()

# %%
#14. Write a Python script that uses the Variance Inflation Factor (VIF) to check for multicollinearity in a dataset with multiple features.

from statsmodels.stats.outliers_influence import variance_inflation_factor

np.random.seed(1)

X=pd.DataFrame(np.random.rand(1000,5),columns=["Feature 1","Feature 2","Feature 3","Feature 4","Feature 5"])

X["Constant"]=5

vif_data=pd.DataFrame()
vif_data["Feature"]=X.columns
vif_data["VIF"]=[variance_inflation_factor(X.values,i)for i in range (X.shape[1])]

print(vif_data)
# Out:
#      Feature        VIF
# 0  Feature 1   1.000953
# 1  Feature 2   1.009350
# 2  Feature 3   1.006039
# 3  Feature 4   1.001105
# 4  Feature 5   1.010079
# 5   Constant  16.068258

# %%
# 15. Write a Python script that generates synthetic data for a polynomial relationship (degree 4), fits a 
# polynomial regression model, and plots the regression curve.  


np.random.seed(1)
n_sample=1000

X = 2 * np.random.rand(n_samples, 1)
y = 4 + 3 * X + np.random.randn(n_samples, 1)


X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,test_size=0.5)

from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=4)

X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test)
model=LinearRegression()
model.fit(X_train_poly,y_train)

y_pred=model.predict(X_test_poly)

plt.figure(figsize=(15,8))
sns.scatterplot(x=X_test.flatten(),y=y_test.flatten(),label="actual")
sns.lineplot(x=X_test.flatten(),y=y_pred.flatten(),color="r",label="regression curve")
plt.title("Polynomial Regression (Degree 4): Synthetic Data")

plt.xlabel("X")
plt.ylabel("y")
plt.legend()
sns.set(style="darkgrid")

plt.show()

# %%
# 16. Write a Python script that creates a machine learning pipeline with data standardization and a multiple 
# linear regression model, and prints the R-squared score.  

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

X = np.random.rand(100, 5)
y = np.random.rand(100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

pipeline=Pipeline([
    ("Scaler",StandardScaler()),
    ("Regression",LinearRegression())
])

pipeline.fit(X_train,y_train)

y_pred=pipeline.predict(X_test)

print("R-squared score:", r2_score(y_test, y_pred))
# Out:
# R-squared score: 0.05391997332848908

# %%
# 17. Write a Python script that performs polynomial regression (degree 3) on a synthetic dataset and plots the regression curve.  

np.random.seed(1)
n_sample=1000

X = 2 * np.random.rand(n_samples, 1)
y = 4 + 3 * X + np.random.randn(n_samples, 1)


X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,test_size=.50)

from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)

X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test)
model=LinearRegression()
model.fit(X_train_poly,y_train)

y_pred=model.predict(X_test_poly)

plt.figure(figsize=(15,8))
sns.scatterplot(x=X_test.flatten(),y=y_test.flatten(),label="actual")
sns.lineplot(x=X_test.flatten(),y=y_pred.flatten(),color="r",label="regression curve")
plt.title("Polynomial Regression (Degree 3): Synthetic Data")

plt.xlabel("X")
plt.ylabel("y")
plt.legend()
sns.set(style="darkgrid")

plt.show()

# %%
# 18. Write a Python script that performs multiple linear regression on a synthetic dataset with 5 features. Print the R-squared score and model coefficients. 

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

np.random.seed(1)
n_sample=1000

X = 2 * np.random.rand(n_samples, 5)
y = 4 + np.sum(3 * X, axis=1) + np.random.randn(n_samples, 1)
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,test_size=0.66)

model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

print(f"The R-Squared :{r2_score(y_test,y_pred)}")
print(f"Model's Coefficient :{model.coef_}")
# Out:
# The R-Squared :0.004153511489147039
# Model's Coefficient :[[ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]
#  [ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]
#  [ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]
#  ...
#  [ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]
#  [ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]
#  [ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]]

# %%
# 19. Write a Python script that generates synthetic data for linear regression, fits a model, and visualizes the 
# data points along with the regression line.  

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

np.random.seed(50)

n_samples=1000

X = 2 * np.random.rand(n_samples, 1)
y = 4 + 3 * X + np.random.randn(n_samples, 1)

pd.DataFrame({"Feature":X.flatten(),"Target":y.flatten()})


from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

model = LinearRegression()

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

sns.set(style="darkgrid")

plt.figure(figsize=(10,8))
sns.scatterplot(x=X.flatten(),y=y.flatten(),label="Actual")
sns.lineplot(x=X_test.flatten(), y=y_pred.flatten(), color="r", label="Regression Line")
plt.title("Linear Regression: Synthetic Data")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
# 20. Create a synthetic dataset with 3 features and perform multiple linear regression. Print the model's R-
# squared score and coefficients.  


np.random.seed(1)
n_sample=1000

X = 2 * np.random.rand(n_samples, 5)
y = 1 + np.sum(3 * X, axis=1) + np.random.randn(n_samples, 1)
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,test_size=0.66)

model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

print("R-squared score:", r2_score(y_test, y_pred))
print("Coefficients:", model.coef_)
# Out:
# R-squared score: 0.004153511489147075
# Coefficients: [[ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]
#  [ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]
#  [ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]
#  ...
#  [ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]
#  [ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]
#  [ 0.09368544 -0.07213688 -0.02399978 -0.08507762  0.00410799]]

# %%
# 21. Write a Python script that demonstrates how to serialize and deserialize machine learning models using 
# joblib instead of pickling. 

np.random.seed(1)
X = np.random.rand(100, 5)
y = np.random.rand(100)

X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,test_size=0.2)

model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

import joblib

# serialize 

joblib_file="Linear_Regression_model.joblib"
joblib_dump=joblib.dump(model,joblib_file)

print(f"Model serialized to {joblib_file}")

# deserialize

loaded_data=joblib.load(joblib_file)

y_pred=loaded_data.predict(X)

print(y_pred)
# Out:
# Model serialized to Linear_Regression_model.joblib
# [0.42921513 0.43234741 0.43107908 0.47706298 0.42268077 0.34722127
#  0.51624303 0.53075865 0.42180373 0.48080699 0.45945375 0.41842923
#  0.51239089 0.43980131 0.35262804 0.45535744 0.49437518 0.47958188
#  0.49361439 0.52053654 0.50364999 0.44226421 0.50787129 0.52009213
#  0.37692027 0.52692201 0.50003669 0.44330379 0.40416965 0.49639506
#  0.53648972 0.39600166 0.47788243 0.43504503 0.50830676 0.44869504
#  0.49141457 0.41899424 0.4353818  0.34237998 0.48985355 0.42996841
#  0.47851647 0.48340077 0.39840495 0.45663983 0.5079416  0.41886286
#  0.50143232 0.38181053 0.46394066 0.46740385 0.47597423 0.47502929
#  0.4451545  0.41054373 0.50635844 0.4664764  0.48764269 0.39774715
#  0.50016448 0.41074782 0.4615902  0.42779039 0.44773156 0.43814773
#  0.43634896 0.49308349 0.51003133 0.47929702 0.43147278 0.43943078
#  0.46927245 0.500145   0.38945616 0.5123179  0.55007085 0.49542745
# ...

# %%
# 22. Write a Python script to perform linear regression with categorical features using one-hot encoding. Use 
# the Seaborn 'tips' dataset.  

df = sns.load_dataset("tips")

numerical_data = df.select_dtypes(include=['number'])
categorical_data = df.select_dtypes(exclude=['number'])
numerical_data.reset_index(drop=True, inplace=True)

from sklearn.preprocessing import OneHotEncoder

one_hot = OneHotEncoder(sparse_output=False)
categorical_encoded = one_hot.fit_transform(categorical_data)
encoded_df = pd.DataFrame(categorical_encoded, columns=one_hot.get_feature_names_out(categorical_data.columns))
encoded_df.reset_index(drop=True, inplace=True)

df_encoded = pd.concat([numerical_data, encoded_df], axis=1)

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,test_size=0.2)


model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

print("R-squared score:", r2_score(y_test, y_pred))
print("Coefficients:", model.coef_)
# Out:
# R-squared score: -0.05671780990317066
# Coefficients: [-0.04347434  0.06792484  0.13211354 -0.0477179  -0.04039882]

# %%
# 23. Compare Ridge Regression with Linear Regression on a synthetic dataset and print the coefficients and R-squared score.  

np.random.seed(500)

n_samples=1000

X = 2 * np.random.rand(n_samples, 1)
y = 4 + 3 * X + np.random.randn(n_samples, 1)

from sklearn.linear_model import LinearRegression

X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,test_size=0.6)

model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

print("Linear Regression's R-Squared score :",r2_score(y_test,y_pred))
print("Linear Regression's Coefficients :",model.coef_)

print("==========================================================")

from sklearn.linear_model import Ridge

model1=Ridge()
model1.fit(X_train,y_train)
y_pred_redge=model1.predict(X_test)

print("Ridge Regression's R-Squared score :",r2_score(y_test,y_pred_redge))
print("Ridge Regression's Coefficients :",model.coef_)
# Out:
# Linear Regression's R-Squared score : 0.7259788751870978
# Linear Regression's Coefficients : [[3.04867542]]
# ...
# Ridge Regression's R-Squared score : 0.7266621710308068
# Ridge Regression's Coefficients : [[3.04867542]]

# %%
# 24. Write a Python script that uses cross-validation to evaluate a Linear Regression model on a synthetic dataset.  

np.random.seed(1)
X = np.random.rand(100, 5)
y = np.random.rand(100)

from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.linear_model import LinearRegression

X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,test_size=0.6)

model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

cross_vs=cross_val_score(model,X,y,cv=5)

print(f"cross-validation: {cross_vs}")
# Out:
# cross-validation: [-0.27018242 -0.17435445 -0.05739283 -0.12405978 -0.2012859 ]

# %%
# 25. Write a Python script that compares polynomial regression models of different degrees and prints the R-
# squared score for each.

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

def compare_degree(degree):
    poly = PolynomialFeatures(degree=degree)
    X_train_poly = poly.fit_transform(X_train)
    X_test_poly = poly.transform(X_test)
    
    model = LinearRegression()
    model.fit(X_train_poly, y_train)
    
    y_pred = model.predict(X_test_poly)
    
    r2 = r2_score(y_test, y_pred)
    
    return r2

degrees = [1, 2, 3, 4, 5]
result = {}

for degree in degrees:
    r2 = compare_degree(degree)
    result[degree] = {"R_squared": r2}

for degree, metrics in result.items():
    print(f"Degree: {degree}")
    print(f"R-squared: {metrics['R_squared']}")
# Out:
# Degree: 1
# R-squared: -0.15857379052153342
# Degree: 2
# R-squared: -0.5381942949475416
# Degree: 3
# R-squared: -3.913126154187599
# Degree: 4
# R-squared: -3.472531636257269
# Degree: 5
# R-squared: -3.5331225804524014
